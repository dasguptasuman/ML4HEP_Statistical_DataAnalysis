# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import comb
from scipy.stats import norm
random_numbers = # generate binomial distribution of 10000 events with each events with 10 trials

# %%
p = np.linspace(0,1,500)

# %%
prior =[]
# Take prior  
plt.plot(p,prior)
plt.show()

k = 0

for i in random_numbers:
    posterior = []
    h = 0
    total = 0
    avg = 0
    for j in p:
        p_post = #calculate (likelihood * prior probablity)
        posterior.append(p_post)
        avg = avg + p_post*j
        total = total + p_post
        h=h+1
    if abs((avg/total - .5))< .01:
        break
    prior = # update prior probablity
    k = k+1;
print("number of steps after which we get actual distribution  : " ,k-1)
plt.plot(p,posterior)
plt.show()
# Out:
# number of steps after which we get actual distribution  :  34
